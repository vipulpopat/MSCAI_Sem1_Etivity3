# %% [markdown]
# # E-tivity 3: Clustering and Manifold Learning
#
# ## Student Name: Vipul Popat
# ## Student ID: 18195121

# %% [markdown]
# Use this notebook to complete Tasks 1 and 2 in E-tivity3.

# %% [markdown]
# ### Import Python Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import manifold
from sklearn import cluster
from sklearn import preprocessing

# %%
# Load the dataset into pandas dataframe
df = pd.read_csv("loans_dataset_et3.csv")

# %%
df.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             2483             2466.0          90               180
# 1             4917                0.0         130               360
# 2             4106                0.0          40               180
# 3             3859             3300.0         142               180
# 4             6417                0.0         157               180
#
#    Credit_History
# 0               0
# 1               0
# 2               1
# 3               1
# 4               1

# %%
df.shape
# Out:
# (332, 5)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       332.000000         332.000000  332.000000        332.000000
# mean       5201.093373        1495.508795  140.882530        341.710843
# std        4584.815491        1982.742932   75.544237         61.651497
# min         645.000000           0.000000   17.000000         60.000000
# 25%        2912.750000           0.000000  100.000000        360.000000
# 50%        3858.500000        1211.500000  128.000000        360.000000
# 75%        5818.250000        2250.000000  162.000000        360.000000
# max       39999.000000       20000.000000  600.000000        480.000000
#
#        Credit_History
# count      332.000000
# mean         0.978916
# std          0.143882
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
# to check whether any of the values are null 
df.isna().sum()

df_data = np.array(df.values, dtype=float)

# %% [markdown]
# ## Task 1 (CS5062)
#
# Cluster loans_dataset_et3.csv with the k-Means clustering algorithm and visualise the clustering. Use an appropriate feature-scaling technique and pick a value of k suggested by MDS and t-SNE visualisations of the dataset. Experiment with various values of the parameters of k-Means. Aim at producing a meaningful clustering that allows you to describe the clusters with words. Write a short conclusion about the characteristics of the clusters (max 250 words).

# %%
min_max_scaler = preprocessing.MinMaxScaler()
df_data = min_max_scaler.fit_transform(df_data)

# %% [markdown]
# ### Scatterplot function for visualization of clusters

# %%
colors = np.array(['orange', 'blue', 'lime', 'blue', 'khaki', 'pink', 'green', 'purple'])

# points - a 2D array of (x,y) coordinates of data points
# labels - an array of numeric labels in the interval [0..k-1], one for each point
# centers - a 2D array of (x, y) coordinates of cluster centers
# title - title of the plot

def clustering_scatterplot(points, labels, centers, title):
    # plot the examples, i.e. the data points
    
    n_clusters = np.unique(labels).size
    for i in range(n_clusters):
        h = plt.scatter(points[labels==i,0],
                        points[labels==i,1], 
                        c=colors[i%colors.size],
                        label = 'cluster '+str(i))

    # plot the centers of the clusters
    if centers is not None:
        plt.scatter(centers[:,0], centers[:,1], c='r', marker='*', s=500)

    _ = plt.title(title)
    _ = plt.legend()
    _ = plt.xlabel('x')
    _ = plt.ylabel('y')

# %% [markdown]
# ### Plotting scatter plots with KMeans clustering along with MDS (Multi Dimensional Scaling) and t-SNE to project both the data and the k-Means cluster centers to a 2D space

# %%
for k in range(1,6):
    # Run KMeans algorithm
    clustered_data_sklearn = cluster.KMeans(n_clusters=k, n_init=10,  init='k-means++', max_iter=1000).fit(df_data)
    
    # Create new array composed of data + k centers 
    df_data_and_centers = np.r_[df_data,clustered_data_sklearn.cluster_centers_]

    f, axs = plt.subplots(1, 2, figsize=(15, 5))

    # MDS
    plt.subplot(1, 2, 1)
    XYcoordinates = manifold.MDS(n_components=2).fit_transform(df_data_and_centers)
    clustering_scatterplot(points=XYcoordinates[:-k,:], 
                           labels=clustered_data_sklearn.labels_, 
                           centers=XYcoordinates[-k:,:], 
                           title='MDS manifold - ' + str(k) + ' clusters')

    # TSE
    plt.subplot(1, 2, 2)
    XYcoordinates = manifold.TSNE(n_components=2).fit_transform(df_data_and_centers)
    clustering_scatterplot(points=XYcoordinates[:-k,:], 
                           labels=clustered_data_sklearn.labels_,
                           centers=XYcoordinates[-k:,:], 
                           title='TSNE manifold - ' + str(k) + ' clusters')

    plt.show()

# %%
df['cluster'] = pd.Series(clustered_data_sklearn.labels_, index=df.index)
df.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             2483             2466.0          90               180
# 1             4917                0.0         130               360
# 2             4106                0.0          40               180
# 3             3859             3300.0         142               180
# 4             6417                0.0         157               180
#
#    Credit_History  cluster
# 0               0        1
# 1               0        1
# 2               1        3
# 3               1        3
# 4               1        3

# %%
df.groupby('cluster').mean()
# Out:
#          ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# cluster
# 0            4243.010152         833.756954  110.710660        361.218274
# 1            9153.857143        2098.142857  206.285714        308.571429
# 2            4086.328571        3608.328571  172.757143        360.857143
# 3            5146.966667        1297.126666  116.333333        161.600000
# 4           13798.607143         931.250000  283.428571        357.857143
#
#          Credit_History
# cluster
# 0                   1.0
# 1                   0.0
# 2                   1.0
# 3                   1.0
# 4                   1.0

# %%
df.groupby('cluster').count()
# Out:
#          ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# cluster
# 0                    197                197         197               197
# 1                      7                  7           7                 7
# 2                     70                 70          70                70
# 3                     30                 30          30                30
# 4                     28                 28          28                28
#
#          Credit_History
# cluster
# 0                   197
# 1                     7
# 2                    70
# 3                    30
# 4                    28

# %% [markdown]
# ### Conclusions
# - We can see that higher the (ApplicantIncome + CoapplicantIncome), higher is the LoanAmount given by the bank
# - There are certain cases where the Loan is disbursed by the bank even though there is no credit history
# - There is a very small fraction of the data which has opted for a smaller loan_term considering that the loan_term is in months
# - The large fraction of customers have opted for smaller loan amounts with a higher loan term
