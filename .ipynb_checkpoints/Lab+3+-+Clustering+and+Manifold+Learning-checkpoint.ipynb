# %% [markdown]
# # Lab 3: Clustering and Manifold Learning

# %% [markdown]
# This notebook demonstrates:
# - the k-Means clustering algorithm
# - the use of manifold-learning techniques to project a clustered dataset into a 2D space and visualise it as a scatterplot
#
# It is assumed that the input dataset contains ___only numerical___ attributes. To use this code with a dataset that contains categorical attributes, they first need to be _somehow_ transformed to numerical. How categorical attributes can be represented as numerical may depend on the nature of the dataset.
#
# When you go through this notebook for the first time you may __skip section C__ and go back to it at the end.

# %% [markdown]
# ### A. Import Python Modules and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import manifold #needed for multidimensional scaling (MDS) and t-SNE
from sklearn import cluster #needed for k-Means clustering
from sklearn import preprocessing #needed for scaling attributes to the nterval [0,1]

# %% [markdown]
# #### Load the dataset

# %%
lab3_df = pd.read_csv("./loans_dataset_et3.csv")
lab3_data = np.array(lab3_df.values, dtype=float)
print('(number of examples, number of attributes): ', lab3_data.shape)
# Out:
# (number of examples, number of attributes):  (332, 5)

# %%
# last 5 Rows
lab3_data[-5:,::]
# Out:
# array([[5.4170e+03, 4.1960e+03, 2.6700e+02, 3.6000e+02, 1.0000e+00],
#        [1.6666e+04, 0.0000e+00, 2.7500e+02, 3.6000e+02, 1.0000e+00],
#        [1.0750e+04, 0.0000e+00, 3.1200e+02, 3.6000e+02, 1.0000e+00],
#        [5.9550e+03, 5.6250e+03, 3.1500e+02, 3.6000e+02, 1.0000e+00],
#        [6.1330e+03, 3.9060e+03, 3.2400e+02, 3.6000e+02, 1.0000e+00]])

# %% [markdown]
# ### B. Scale the Data
# Here we scale the values in each column to the interval [0,1]. See https://scikit-learn.org/stable/modules/preprocessing.html for alternative scaling methods. In yout work on this excersise experiment with other scaling techniques to see if they lead to a more insightful clustering.

# %%
min_max_scaler = preprocessing.MinMaxScaler()
lab3_data_min = min_max_scaler.fit_transform(lab3_data)

# With the MoinMax Scaler - the clustering did ont match the visual representation

# So I am going to try a different scaler
from sklearn.preprocessing import RobustScaler
lab3_data_robust = RobustScaler(quantile_range=(25, 75)).fit_transform(lab3_data)

# This was mich worse so I am moving to a different scaler
from sklearn.preprocessing import QuantileTransformer
lab3_data_quantile = QuantileTransformer(output_distribution='uniform').fit_transform(lab3_data)

# %%
# last 5 Rows
lab3_data_min[-5:,::]
# Out:
# array([[0.12125832, 0.2098    , 0.42881647, 0.71428571, 1.        ],
#        [0.40709966, 0.        , 0.44253859, 0.71428571, 1.        ],
#        [0.25677187, 0.        , 0.50600343, 0.71428571, 1.        ],
#        [0.13492911, 0.28125   , 0.51114923, 0.71428571, 1.        ],
#        [0.13945215, 0.1953    , 0.52658662, 0.71428571, 1.        ]])

# %% [markdown]
# ### C. Scatterplot Function (to be used below for visualising a clustering)
#
# Skip this section when you read the notebook for the first time.

# %%
colors = np.array(['orange', 'blue', 'lime', 'blue', 'khaki', 'pink', 'green', 'purple'])

# points - a 2D array of (x,y) coordinates of data points
# labels - an array of numeric labels in the interval [0..k-1], one for each point
# centers - a 2D array of (x, y) coordinates of cluster centers
# title - title of the plot

def clustering_scatterplot(points, labels, centers, title):
    # plot the examples, i.e. the data points
    
    n_clusters = np.unique(labels).size
    for i in range(n_clusters):
        h = plt.scatter(points[labels==i,0],
                        points[labels==i,1], 
                        c=colors[i%colors.size],
                        label = 'cluster '+str(i))

    # plot the centers of the clusters
    if centers is not None:
        plt.scatter(centers[:,0], centers[:,1], c='r', marker='*', s=500)

    _ = plt.title(title)
    _ = plt.legend()
    _ = plt.xlabel('x')
    _ = plt.ylabel('y')

# %%
def twin_plots_MDS_TSNE(k, data_and_centers, plot_rows, plot_start, title=""):
    print("Plotting Graph",plot_start,"&",plot_start+1,"for k =",k)
    XYcoordinates = manifold.MDS(n_components=2).fit_transform(data_and_centers)
    plt.subplot(plot_rows, 2, plot_start)
    clustering_scatterplot(points=XYcoordinates[:-k,:], 
                       labels=clustered_data_sklearn.labels_, 
                       centers=XYcoordinates[-k:,:], 
                       title='MDS k=' + str(k)+ title)
    XYcoordinates = manifold.TSNE(n_components=2).fit_transform(data_and_centers)
    plt.subplot(plot_rows, 2, plot_start + 1)
    clustering_scatterplot(points=XYcoordinates[:-k,:], 
                       labels=clustered_data_sklearn.labels_,
                       centers=XYcoordinates[-k:,:], 
                       title='TSNE k=' + str(k) + title)

# %%
# Plots for k = 3 for different scalers
number_of_scalers = 3
k = 3
fig, ax = plt.subplots(number_of_scalers, 2, figsize=(16, 8*number_of_scalers))

clustered_data_sklearn = cluster.KMeans(n_clusters=k, n_init=10,
                                        max_iter=300, 
                                        init='k-means++').fit(lab3_data_min)
lab3_data_and_centers = np.r_[lab3_data_min,clustered_data_sklearn.cluster_centers_]
twin_plots_MDS_TSNE(k, lab3_data_and_centers, 3, 1, " after minMaxScaler")
clustered_data_sklearn = cluster.KMeans(n_clusters=k, n_init=10,
                                        max_iter=300, 
                                        init='k-means++').fit(lab3_data_robust)
lab3_data_and_centers = np.r_[lab3_data_robust,clustered_data_sklearn.cluster_centers_]
twin_plots_MDS_TSNE(k, lab3_data_and_centers, 3, 3, " after RobustScaler")
clustered_data_sklearn = cluster.KMeans(n_clusters=k, n_init=10,
                                        max_iter=300, 
                                        init='k-means++').fit(lab3_data_quantile)
lab3_data_and_centers = np.r_[lab3_data_quantile,clustered_data_sklearn.cluster_centers_]
twin_plots_MDS_TSNE(k, lab3_data_and_centers, 3, 5, " after Quantile Scaler")

plt.show()
# Out:
# Plotting Graph 1 & 2 for k= 3
# Plotting Graph 3 & 4 for k= 3
# Plotting Graph 5 & 6 for k= 3

# %% [markdown]
# ### D. K-Means Clustering

# %%
lab3_data_and_centers[-k:,:]
# Out:
# array([[0.39014048, 0.73693343, 0.54329861, 0.51670924, 0.9770114 ],
#        [0.83417086, 0.01813204, 0.73652101, 0.48981449, 0.96103887],
#        [0.4183362 , 0.08094481, 0.18225499, 0.47299845, 0.9999999 ]])

# %% [markdown]
# Number of clusters $k$.

# %%
k_max = 4
fig, ax = plt.subplots(k_max-1, 2, figsize=(16, (8*(k_max-1))))
data = lab3_data_quantile

for k in range(2, k_max+1):
    print("Plotting Graphs for k =", k)
    clustered_data_sklearn = cluster.KMeans(n_clusters=k, n_init=10, max_iter=300, init='k-means++').fit(data)
    lab3_data_and_centers = np.r_[data,clustered_data_sklearn.cluster_centers_]
    twin_plots_MDS_TSNE(k, lab3_data_and_centers, k_max-1, (2*k)-3)
#     XYcoordinates = manifold.MDS(n_components=2).fit_transform(lab3_data_and_centers)
#     plt.subplot(k_max, 2, (2 *k)-1)
#     clustering_scatterplot(points=XYcoordinates[:-k,:], 
#                        labels=clustered_data_sklearn.labels_, 
#                        centers=XYcoordinates[-k:,:], 
#                        title='MDS k=' + str(k))
#     XYcoordinates = manifold.TSNE(n_components=2).fit_transform(lab3_data_and_centers)
#     plt.subplot(k_max, 2, (2 *k))
#     clustering_scatterplot(points=XYcoordinates[:-k,:], 
#                        labels=clustered_data_sklearn.labels_,
#                        centers=XYcoordinates[-k:,:], 
#                        title='TSNE k=' + str(k))
plt.show()
# Out:
# Plotting Graphs for k = 2
# Plotting Graph 1 & 2 for k= 2
# Plotting Graphs for k = 3
# Plotting Graph 3 & 4 for k= 3
# Plotting Graphs for k = 4
# Plotting Graph 5 & 6 for k= 4

# %% [markdown]
# #### Run k-Means
#
# See https://scikit-learn.org/stable/modules/clustering.html for alternative clustering methods.

# %%
clustered_data_sklearn = cluster.KMeans(n_clusters=k, n_init=10, max_iter=300, init='k-means++').fit(lab3_data)

# %% [markdown]
# ### E. Apply a manifold-learning technique to project the data set to a 2D space
#
# https://scikit-learn.org/stable/modules/manifold.html

# %%
# append the cluster centers to the dataset
lab3_data_and_centers = np.r_[lab3_data,clustered_data_sklearn.cluster_centers_]

# %% [markdown]
# #### E1. Apply multi-dimensional scaling (MDS) to project both the data and the k-Means cluster centers to a 2D space

# %%
# project both th data and the k-Means cluster centers to a 2D space
XYcoordinates = manifold.MDS(n_components=2).fit_transform(lab3_data_and_centers)
print("transformation complete")
# Out:
# transformation complete

# %%
# plot the transformed examples and the centers
# use the cluster assignment to colour the examples
clustering_scatterplot(points=XYcoordinates[:-k,:], 
                       labels=clustered_data_sklearn.labels_, 
                       centers=XYcoordinates[-k:,:], 
                       title='MDS')

# %% [markdown]
# #### E2. Apply t-SNE to project both the data and the k-Means cluster centers to a 2D space

# %%
# project both th data and the k-Means cluster centers to a 2D space
XYcoordinates = manifold.TSNE(n_components=2).fit_transform(lab3_data_and_centers)
print("transformation complete")
# Out:
# transformation complete

# %%
# plot the transformed examples and the centers
# use the cluster assignment to colour the examples
# plot the transformed examples and the centers
# use the cluster assignment to colour the examples
clustering_scatterplot(points=XYcoordinates[:-k,:], 
                       labels=clustered_data_sklearn.labels_,
                       centers=XYcoordinates[-k:,:], 
                       title='TSNE')

# %% [markdown]
# ### F. Cluster Analysis

# %% [markdown]
# #### Add the cluster labels as an extra column in the original dataframe

# %%
lab3_df['cluster'] = pd.Series(clustered_data_sklearn.labels_, index=lab3_df.index)

# %%
lab3_df.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             2483             2466.0          90               180
# 1             4917                0.0         130               360
# 2             4106                0.0          40               180
# 3             3859             3300.0         142               180
# 4             6417                0.0         157               180
#
#    Credit_History  cluster
# 0               0        1
# 1               0        1
# 2               1        1
# 3               1        1
# 4               1        1

# %%
lab3_df.tail()
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 327             5417             4196.0         267               360
# 328            16666                0.0         275               360
# 329            10750                0.0         312               360
# 330             5955             5625.0         315               360
# 331             6133             3906.0         324               360
#
#      Credit_History  cluster
# 327               1        1
# 328               1        0
# 329               1        1
# 330               1        1
# 331               1        1

# %% [markdown]
# #### Compute the mean value of each attribute for each cluster

# %%
lab3_df.groupby('cluster').mean()
# Out:
#          ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# cluster
# 0           19097.250000         400.700000  242.900000        333.000000
# 1            4310.314103        1565.688846  134.342949        342.269231
#
#          Credit_History
# cluster
# 0              0.950000
# 1              0.980769

# %% [markdown]
# #### Conclusion
#
# By looking at the table above we can argue that:
# * Cluster 2 are large iris flowers with the largest petals out of the three types.
# * Cluster 1 are iris flowers with small petals (notably smaller than the other two types) but with somehow wide sepals, the widest sepals of all three types. This is also the cluster that is clearly differentiated from the other two clusters in the scatter plots.
# * Cluster 0 flowers are slightly smaller than cluster 2 flowers with a most notable difference in the width of the petals.
#
# _Note that this conclusion is true for this run of k-Means. If the code is executed again, k-Means may produce either different clusters or the same clusters but in a different order._

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt


#data = X[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)']]

sse = {}
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(lab3_data_min)
    sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center
plt.figure()
plt.title("Elbow Graph for KMeans")
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

sse = {}
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(lab3_data_quantile)
    sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center
plt.figure()
plt.title("Elbow Graph for KMeans")
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()
